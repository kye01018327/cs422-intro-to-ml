# %%
import helpers as hp
import numpy as np
import matplotlib.pyplot as plt
from svm import distance_point_to_hyperplane, compute_margin, plot_data_and_boundary

# %%
def cprint(*args):
    print(*args, sep='\n', end='\n\n')

# %%
# Parameters
num = 3
training_data = hp.generate_training_data_binary(num)
cprint(training_data)
# Out:
# [[ 3.  2.  1.]
#  [ 6.  2.  1.]
#  [ 3.  6.  1.]
#  [ 4.  4.  1.]
#  [ 5.  4.  1.]
#  [-1. -2. -1.]
#  [-2. -4. -1.]
#  [-3. -3. -1.]
#  [-4. -2. -1.]
#  [-4. -4. -1.]]

# %%
# Preprocessing
# Separate into classes
positive_set = []
negative_set = []
for pt in training_data:
    label = pt[-1]
    if label == 1:
        positive_set.append(pt)
    elif label == -1:
        negative_set.append(pt)

positive_set = np.array(positive_set)
negative_set = np.array(negative_set)
cprint(positive_set,negative_set)
# Out:
# [[3. 2. 1.]
#  [6. 2. 1.]
#  [3. 6. 1.]
#  [4. 4. 1.]
#  [5. 4. 1.]]
# [[-1. -2. -1.]
#  [-2. -4. -1.]
#  [-3. -3. -1.]
#  [-4. -2. -1.]
#  [-4. -4. -1.]]

# %%
# Enumerate all possible support-vector combinations

# 2 support vectors

two_sv = []
for pos_pt in positive_set:
    for neg_pt in negative_set:
        two_sv.append((pos_pt, neg_pt))
two_sv = np.array(two_sv)

cprint(two_sv[:3])
# Out:
# [[[ 3.  2.  1.]
#   [-1. -2. -1.]]
#
#  [[ 3.  2.  1.]
#   [-2. -4. -1.]]
#
#  [[ 3.  2.  1.]
#   [-3. -3. -1.]]]

# %%
# Compute w and b for each pair of support vectors
w_b = []
for pair in two_sv:
    positive_pt = pair[0][:-1]
    negative_pt = pair[1][:-1]
    dist = positive_pt - negative_pt
    dir_w = dist / np.linalg.norm(dist)
    gamma = np.linalg.norm(dist) / 2       # distance/2
    this_w = dir_w * (1 / gamma)           # = dir * (2 / |dist|)
    b = 1 - this_w @ positive_pt

    print(this_w,b)
    w_b.append((this_w,b))
    # cprint(dir_w, gamma, this_w, b)
# cprint(w_b)
# Out:
# [0.25 0.25] -0.24999999999999956
# [0.16393443 0.19672131] 0.11475409836065564
# [0.19672131 0.16393443] 0.08196721311475408
# [0.21538462 0.12307692] 0.10769230769230753
# [0.16470588 0.14117647] 0.22352941176470587
# [0.21538462 0.12307692] -0.5384615384615388
# [0.16 0.12] -0.20000000000000018
# [0.16981132 0.09433962] -0.2075471698113207
# [0.17241379 0.06896552] -0.1724137931034484
# [0.14705882 0.08823529] -0.0588235294117645
# [0.1 0.2] -0.5
# [0.08 0.16] -0.19999999999999996
# [0.1025641  0.15384615] -0.23076923076923062
# [0.12389381 0.14159292] -0.22123893805309724
# [0.09395973 0.13422819] -0.08724832214765121
# [0.16393443 0.19672131] -0.4426229508196722
# [0.12 0.16] -0.1200000000000001
# [0.14285714 0.14285714] -0.1428571428571428
# [0.16 0.12] -0.1200000000000001
# [0.125 0.125] 2.220446049250313e-16
# [0.16666667 0.16666667] -0.5000000000000002
# [0.12389381 0.14159292] -0.18584070796460184
# [0.14159292 0.12389381] -0.20353982300884943
# [0.15384615 0.1025641 ] -0.1794871794871793
# [0.12413793 0.11034483] -0.0620689655172415

# %%
# 3 support vectors

three_sv_pos = []
for i in range(len(positive_set)):
    for j in range(i + 1, len(positive_set)):
        for neg_pt in negative_set:
            three_sv_pos.append((positive_set[i], positive_set[j], neg_pt))

three_sv_neg = []
for i in range(len(negative_set)):
    for j in range(i + 1, len(negative_set)):
        for pos_pt in positive_set:
            three_sv_neg.append((negative_set[i], negative_set[j], pos_pt))

three_sv_pos = np.array(three_sv_pos)
three_sv_neg = np.array(three_sv_neg)
print(three_sv_neg)
# Out:
# [[[-1. -2. -1.]
#   [-2. -4. -1.]
#   [ 3.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-2. -4. -1.]
#   [ 6.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-2. -4. -1.]
#   [ 3.  6.  1.]]
#
#  [[-1. -2. -1.]
#   [-2. -4. -1.]
#   [ 4.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-2. -4. -1.]
#   [ 5.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-3. -3. -1.]
#   [ 3.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-3. -3. -1.]
#   [ 6.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-3. -3. -1.]
#   [ 3.  6.  1.]]
#
#  [[-1. -2. -1.]
#   [-3. -3. -1.]
#   [ 4.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-3. -3. -1.]
#   [ 5.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -2. -1.]
#   [ 3.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -2. -1.]
#   [ 6.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -2. -1.]
#   [ 3.  6.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -2. -1.]
#   [ 4.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -2. -1.]
#   [ 5.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -4. -1.]
#   [ 3.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -4. -1.]
#   [ 6.  2.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -4. -1.]
#   [ 3.  6.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -4. -1.]
#   [ 4.  4.  1.]]
#
#  [[-1. -2. -1.]
#   [-4. -4. -1.]
#   [ 5.  4.  1.]]
#
#  [[-2. -4. -1.]
#   [-3. -3. -1.]
#   [ 3.  2.  1.]]
#
#  [[-2. -4. -1.]
#   [-3. -3. -1.]
#   [ 6.  2.  1.]]
#
#  [[-2. -4. -1.]
#   [-3. -3. -1.]
#   [ 3.  6.  1.]]
#
#  [[-2. -4. -1.]
#   [-3. -3. -1.]
#   [ 4.  4.  1.]]
#
#  [[-2. -4. -1.]
#   [-3. -3. -1.]
#   [ 5.  4.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -2. -1.]
#   [ 3.  2.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -2. -1.]
#   [ 6.  2.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -2. -1.]
#   [ 3.  6.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -2. -1.]
#   [ 4.  4.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -2. -1.]
#   [ 5.  4.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -4. -1.]
#   [ 3.  2.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -4. -1.]
#   [ 6.  2.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -4. -1.]
#   [ 3.  6.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -4. -1.]
#   [ 4.  4.  1.]]
#
#  [[-2. -4. -1.]
#   [-4. -4. -1.]
#   [ 5.  4.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -2. -1.]
#   [ 3.  2.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -2. -1.]
#   [ 6.  2.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -2. -1.]
#   [ 3.  6.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -2. -1.]
#   [ 4.  4.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -2. -1.]
#   [ 5.  4.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -4. -1.]
#   [ 3.  2.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -4. -1.]
#   [ 6.  2.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -4. -1.]
#   [ 3.  6.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -4. -1.]
#   [ 4.  4.  1.]]
#
#  [[-3. -3. -1.]
#   [-4. -4. -1.]
#   [ 5.  4.  1.]]
#
#  [[-4. -2. -1.]
#   [-4. -4. -1.]
#   [ 3.  2.  1.]]
#
#  [[-4. -2. -1.]
#   [-4. -4. -1.]
#   [ 6.  2.  1.]]
#
#  [[-4. -2. -1.]
#   [-4. -4. -1.]
#   [ 3.  6.  1.]]
#
#  [[-4. -2. -1.]
#   [-4. -4. -1.]
#   [ 4.  4.  1.]]
#
#  [[-4. -2. -1.]
#   [-4. -4. -1.]
#   [ 5.  4.  1.]]]

# %%
# Compute w for each triplet of support vectors

for triplet in three_sv_pos:
    two_pts = (triplet[0][:-1], triplet[1][:-1])
    one_pt = triplet[2][:-1]
    midpt = (two_pts[0] + two_pts[1]) / 2     # make midpt a numpy array
    dist = midpt - one_pt
    dir_w = dist / np.linalg.norm(dist)

    gamma = np.linalg.norm(dist) / 2          # margin = half distance
    this_w = dir_w * (1 / gamma)              # same scaling fix

    # If one_pt is the negative SV:
    b = -1 - this_w @ one_pt                  # for negative-class SV
    # If one_pt is positive:
    # b = 1 - this_w @ one_pt

    print(this_w,b)
    w_b.append((this_w,b))

for triplet in three_sv_neg:
    two_pts = (triplet[0][:-1], triplet[1][:-1])
    one_pt = triplet[2][:-1]
    midpt = (two_pts[0] + two_pts[1]) / 2     # make midpt a numpy array
    dist = midpt - one_pt
    dir_w = dist / np.linalg.norm(dist)
    
    gamma = np.linalg.norm(dist) / 2          # margin = half distance
    this_w = dir_w * (1 / gamma)              # same scaling fix
    
    # If one_pt is the negative SV:
    b = -1 - this_w @ one_pt                  # for negative-class SV
    # If one_pt is positive:
    # b = 1 - this_w @ one_pt
    print(this_w,b)
    w_b.append((this_w,b))
# Out:
# [0.23783784 0.17297297] -0.4162162162162163
# [0.16613419 0.15335463] -0.054313099041533475
# [0.18461538 0.12307692] -0.07692307692307687
# [0.19263456 0.09065156] -0.04815864022662886
# [0.15704388 0.1108545 ] 0.07159353348729791
# [0.15384615 0.23076923] -0.3846153846153846
# [0.11235955 0.17977528] -0.05617977528089879
# [0.14117647 0.16470588] -0.08235294117647063
# [0.16470588 0.14117647] -0.05882352941176472
# [0.12389381 0.14159292] 0.06194690265486713
# [0.19889503 0.22099448] -0.3591160220994474
# [0.13880126 0.17665615] -0.015772870662460803
# [0.16613419 0.15335463] -0.04153354632587847
# [0.18461538 0.12307692] -0.01538461538461533
# [0.14251781 0.13301663] 0.10213776722090229
# [0.2 0.2] -0.4
# [0.14117647 0.16470588] -0.05882352941176472
# [0.16470588 0.14117647] -0.08235294117647052
# [0.17977528 0.11235955] -0.05617977528089879
# [0.14159292 0.12389381] 0.06194690265486713
# [0.16603774 0.18113208] -0.4716981132075472
# [0.12235294 0.15058824] -0.15294117647058814
# [0.14251781 0.13301663] -0.17339667458432317
# [0.15704388 0.1108545 ] -0.15011547344110865
# [0.12477064 0.11743119] -0.031192660550458662
# [0.19672131 0.16393443] -0.47540983606557374
# [0.14285714 0.14285714] -0.1428571428571429
# [0.16 0.12] -0.15999999999999992
# [0.16981132 0.09433962] -0.1320754716981133
# [0.13846154 0.10769231] -0.01538461538461533
# [0.19330855 0.14869888] -0.5092936802973979
# [0.14251781 0.13301663] -0.18289786223277926
# [0.15704388 0.1108545 ] -0.19630484988452668
# [0.164859  0.0867679] -0.16702819956616044
# [0.13644524 0.1005386 ] -0.05206463195691213
# [0.1299639  0.20216606] -0.46570397111913364
# [0.0988764  0.16179775] -0.15505617977528097
# [0.12235294 0.15058824] -0.18117647058823527
# [0.14251781 0.13301663] -0.16389548693586709
# [0.10928962 0.13114754] -0.03825136612021851
# [0.13513514 0.18918919] -0.4864864864864864
# [0.1025641  0.15384615] -0.17948717948717963
# [0.12389381 0.14159292] -0.20353982300884965
# [0.14159292 0.12389381] -0.18584070796460184
# [0.11034483 0.12413793] -0.06206896551724128
# [0.16603774 0.18113208] -0.4716981132075472
# [0.12235294 0.15058824] -0.15294117647058814
# [0.14251781 0.13301663] -0.17339667458432317
# [0.15704388 0.1108545 ] -0.15011547344110865
# [0.12477064 0.11743119] -0.031192660550458662
# [-0.19889503 -0.22099448] 0.03867403314917128
# [-0.18461538 -0.12307692] 0.3538461538461539
# [-0.08888889 -0.17777778] 0.3333333333333335
# [-0.13880126 -0.17665615] 0.26182965299684513
# [-0.14246575 -0.15342466] 0.3260273972602743
# [-0.22099448 -0.19889503] 0.0607734806629836
# [-0.18991098 -0.10682493] 0.35311572700296745
# [-0.10282776 -0.1748072 ] 0.35732647814910035
# [-0.15335463 -0.16613419] 0.2779552715654954
# [-0.15342466 -0.14246575] 0.3369863013698633
# [-0.23783784 -0.17297297] 0.059459459459459296
# [-0.19263456 -0.09065156] 0.33711048158640233
# [-0.11671088 -0.16976127] 0.3687002652519895
# [-0.16613419 -0.15335463] 0.2779552715654954
# [-0.16260163 -0.1300813 ] 0.3333333333333335
# [-0.19909502 -0.18099548] -0.040723981900452566
# [-0.1748072  -0.10282776] 0.2544987146529565
# [-0.0988764  -0.16179775] 0.26741573033707855
# [-0.14246575 -0.15342466] 0.18356164383561668
# [-0.14251781 -0.13301663] 0.24465558194774317
# [-0.18181818 -0.18181818] -0.09090909090909083
# [-0.16585366 -0.10731707] 0.20975609756097557
# [-0.09128631 -0.15767635] 0.21991701244813266
# [-0.1319797  -0.15228426] 0.13705583756345185
# [-0.13333333 -0.13333333] 0.19999999999999996
# [-0.19672131 -0.16393443] -0.08196721311475408
# [-0.16981132 -0.09433962] 0.2075471698113207
# [-0.1025641  -0.15384615] 0.23076923076923062
# [-0.14285714 -0.14285714] 0.1428571428571428
# [-0.14159292 -0.12389381] 0.20353982300884943
# [-0.16666667 -0.16666667] -0.16666666666666663
# [-0.15384615 -0.1025641 ] 0.12820512820512797
# [-0.08823529 -0.14705882] 0.1470588235294117
# [-0.12389381 -0.14159292] 0.06194690265486713
# [-0.125 -0.125] 0.12499999999999978
# [-0.208 -0.144] -0.08799999999999997
# [-0.1719457  -0.08144796] 0.1945701357466061
# [-0.11353712 -0.14847162] 0.23144104803493448
# [-0.15228426 -0.1319797 ] 0.13705583756345185
# [-0.14847162 -0.11353712] 0.19650655021834074
# [-0.17931034 -0.15172414] -0.1586206896551725
# [-0.15767635 -0.09128631] 0.12863070539419086
# [-0.09811321 -0.14339623] 0.15471698113207544
# [-0.13333333 -0.13333333] 0.06666666666666665
# [-0.13229572 -0.11673152] 0.12840466926070038
# [-0.18918919 -0.13513514] -0.16216216216216217
# [-0.16 -0.08] 0.11999999999999988
# [-0.10769231 -0.13846154] 0.15384615384615397
# [-0.14159292 -0.12389381] 0.06194690265486713
# [-0.13846154 -0.10769231] 0.12307692307692308

# %%
# Verify decision boundary is valid

verified_w_b = []
for w, b in w_b:
    is_valid = True
    for pt in training_data:
        x = pt[:-1]
        y = pt[-1]
        prediction = w @ x + b
        score = y * prediction
        if score < 1:
            is_valid = False
            break
    if is_valid:
        verified_w_b.append((w, b))
        print(w,b)

print(verified_w_b)
# Out:
# []

# %%
# Find w, b with largest margin
largest_margin = 0
for w,b in verified_w_b:
    this_margin = compute_margin(training_data, w, b)
    print(this_margin)
    if this_margin > largest_margin:
        largest_margin = this_margin
        final_w, final_b = w, b

print(final_w, final_b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       7         largest_margin = this_margin
#       8         final_w, final_b = w, b
# ---> 10 print(final_w, final_b)
#
# NameError: name 'final_w' is not defined

# %%
# # 1. Define the parameters (learned from a classification model)
# w1 = 2.0  # Weight for feature x1
# w2 = -1.5 # Weight for feature x2
# b = -3.0  # Bias

# # The decision boundary equation is: 2.0*x1 - 1.5*x2 - 3.0 = 0

# # 2. Define the x1 (horizontal axis) range
# x1_min, x1_max = -1, 5
# x1 = np.linspace(x1_min, x1_max)

# # 3. Calculate the corresponding x2 (vertical axis) values
# # Rearrange: x2 = (-w1*x1 - b) / w2
# x2 = (-w1 * x1 - b) / w2

# # 4. Plot the line
# plt.plot(x1, x2, color='red')

# plt.grid(True)
# plt.show()

# %%
plot_data_and_boundary(training_data, final_w, final_b)

# %%
for w,b in verified_w_b:
    plot_data_and_boundary(training_data, w, b)
