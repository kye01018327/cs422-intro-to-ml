# %%
import numpy as np
import helpers as hp
import svm

# %%
for i in range(1,5):
    hp.plot_training_data_binary(hp.generate_training_data_binary(i))

# %%
for i in range(1,3):
    hp.plot_training_data_multi(hp.generate_training_data_multi(i)[0])

# %%
dataset = np.array(hp.generate_training_data_binary(2))
w,b,S = svm.svm_train_brute(dataset)
svm.plot_data_and_boundary(dataset, w, b)
