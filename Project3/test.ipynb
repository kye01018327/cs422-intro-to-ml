# %%
import helpers as hp
import numpy as np

# %%
data = hp.generate_training_data_binary(1)
data
# Out:
# array([[-5.,  0.,  1.],
#        [-4.,  0.,  1.],
#        [-3.,  0.,  1.],
#        [-2.,  0.,  1.],
#        [-1.,  0.,  1.],
#        [ 1.,  0., -1.],
#        [ 2.,  0., -1.],
#        [ 3.,  0., -1.],
#        [ 4.,  0., -1.],
#        [ 5.,  0., -1.]])

# %%
data[0][-2]
# Out:
# np.float64(0.0)
